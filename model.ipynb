# %%
# %pip install wandb
# %pip install ultralytics
import wandb
import ultralytics
# Out:
# Python(81212) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
# Note: you may need to restart the kernel to use updated packages.
# Python(81213) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
wandb.init(project='SeoulTechML', name='yolo11m')
# Out:
# Finishing last run (ID:m7bx2nus) before initializing another...
#  View run <strong style="color:#cdcd00">yolo11m</strong> at: <a href='https://wandb.ai/jesse-sillman-xamk/SeoulTechML/runs/m7bx2nus' target="_blank">https://wandb.ai/jesse-sillman-xamk/SeoulTechML/runs/m7bx2nus</a><br/> View project at: <a href='https://wandb.ai/jesse-sillman-xamk/SeoulTechML' target="_blank">https://wandb.ai/jesse-sillman-xamk/SeoulTechML</a><br/>Synced 2 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241130_181524-m7bx2nus/logs</code>
# Successfully finished last run (ID:m7bx2nus). Initializing new run:<br/>
# Python(81216) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/Users/jessesillman/Documents/SeoulTechCourses/ML/Project/FinalProject/SeoulTechML/wandb/run-20241201_201001-v7p15t03</code>
# ...

# %%
ultralytics.SETTINGS['loggers'] = ['wandb']
ultralytics.SETTINGS['wandb'] = {'project': 'SeoulTechML', 'name': 'yolo11m'}

# %%
model = ultralytics.YOLO('yolo11m.pt')
# Out:
# ...
# ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt...
# Python(81245) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ######################################################################## 100.0%

# %%
import torch
print(torch.backends.mps.is_available())

results = model.train(data="yolo.yaml", epochs=3, save=True, device="cpu")
# Out:
# True
# Ultralytics 8.3.39 🚀 Python-3.10.7 torch-2.5.1 CPU (Apple M1)
# ...

# %%
import cv2

file_path = "/Users/jessesillman/Documents/SeoulTechCourses/ML/Project/FinalProject/SeoulTechML/datasets/train/images/maksssksksss356.png"
img = cv2.imread(file_path)

if img is None:
    print(f"The file {file_path} is corrupted or unreadable.")
else:
    print(f"The file {file_path} is accessible and readable.")

# %%
final_model = ultralytics.YOLO('runs/detect/train/weights/best.pt')

# %%
filename="maksssksksss79"
final_model.predict(f"datasets/test/images/{filename}.png", save=True)
# Out:
# image 1/1 /Users/jessesillman/Documents/SeoulTechCourses/ML/Project/FinalProject/SeoulTechML/datasets/test/images/maksssksksss79.png: 640x640 1 without_mask, 339.1ms
# Speed: 2.7ms preprocess, 339.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'with_mask', 1: 'mask_weared_incorrect', 2: 'without_mask'}
#  obb: None
#  orig_img: array([[[114, 117, 121],
#          [116, 119, 123],
#          [117, 120, 124],
#          ...,
#          [129, 132, 136],
#          [130, 133, 137],
#          [131, 134, 138]],
#
#         [[114, 117, 121],
#          [116, 118, 123],
#          [117, 120, 124],
#          ...,
#          [129, 132, 136],
#          [130, 132, 136],
#          [131, 133, 138]],
#
#         [[114, 117, 121],
#          [115, 118, 122],
# ...

# %%
import PIL

# %%
PIL.Image.open(f"runs/detect/predict/{filename}.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400>
